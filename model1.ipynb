# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import datasets
from keras.layers import Dense, Flatten , Conv2D, MaxPooling2D , Dropout
from keras import datasets,Sequential

(train_img, train_label),(test_img, test_label) = datasets.mnist.load_data()
train_img=train_img/255.0
train_img=train_img.reshape(-1,28,28,1)


model=Sequential()
model.add(Conv2D(kernel_size=(2,2),padding='valid',filters=64,input_shape=(28,28,1)))
model.add(MaxPooling2D(pool_size=(2,2),padding='valid'))

model.add(Conv2D(kernel_size=(2,2),padding='valid',filters=64))
model.add(MaxPooling2D(pool_size=(2,2),padding='valid'))

model.add(Conv2D(kernel_size=(2,2),padding='valid',filters=64))
model.add(MaxPooling2D(pool_size=(2,2),padding='valid'))

model.add(Flatten())
model.add(Dense(128,activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(64,activation='relu'))
model.add(Dropout(0.1))
model.add(Dense(10,activation='softmax'))


model.summary()

model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])
model.fit(train_img,train_label,epochs=20,batch_size=128)
model.save('my_model1.keras')
#test_loss,test_acc=model.evaluate(test_img,test_label)
#print(test_acc)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_4 (Conv2D)           (None, 27, 27, 64)        320
#
#  max_pooling2d_3 (MaxPoolin  (None, 13, 13, 64)        0
#  g2D)
#
#  conv2d_5 (Conv2D)           (None, 12, 12, 64)        16448
#
#  max_pooling2d_4 (MaxPoolin  (None, 6, 6, 64)          0
#  g2D)
#
#  conv2d_6 (Conv2D)           (None, 5, 5, 64)          16448
#
#  max_pooling2d_5 (MaxPoolin  (None, 2, 2, 64)          0
#  g2D)
#
#  flatten_1 (Flatten)         (None, 256)               0
#
#  dense_4 (Dense)             (None, 128)               32896
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_5 (Dense)             (None, 64)                8256
#
#  dropout_4 (Dropout)         (None, 64)                0
#
#  dense_6 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 75018 (293.04 KB)
# Trainable params: 75018 (293.04 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/20
# 469/469 [==============================] - 5s 5ms/step - loss: 0.3718 - accuracy: 0.8836
# Epoch 2/20
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1116 - accuracy: 0.9662
# Epoch 3/20
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0812 - accuracy: 0.9752
# Epoch 4/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0643 - accuracy: 0.9808
# Epoch 5/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0553 - accuracy: 0.9822
# Epoch 6/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0456 - accuracy: 0.9860
# Epoch 7/20
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0417 - accuracy: 0.9867
# Epoch 8/20
# 469/469 [==============================] - 3s 5ms/step - loss: 0.0355 - accuracy: 0.9884
# Epoch 9/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0310 - accuracy: 0.9898
# Epoch 10/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0295 - accuracy: 0.9901
# Epoch 11/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0262 - accuracy: 0.9913
# Epoch 12/20
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0256 - accuracy: 0.9913
# Epoch 13/20
# 469/469 [==============================] - 3s 5ms/step - loss: 0.0231 - accuracy: 0.9928
# Epoch 14/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0211 - accuracy: 0.9931
# Epoch 15/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0206 - accuracy: 0.9933
# Epoch 16/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0199 - accuracy: 0.9934
# Epoch 17/20
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0178 - accuracy: 0.9943
# Epoch 18/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0173 - accuracy: 0.9941
# Epoch 19/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0163 - accuracy: 0.9947
# Epoch 20/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0150 - accuracy: 0.9947
